# %%
import pandas as pd
import numpy as np

# %%
# Read matplotlib for more info.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# plt.show() for idle after write code

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional method
plt.plot(x,y)

# %%
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.plot(x,y)
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1) # Row - Column
plt.plot(x,y,"r")

plt.subplot(1,2,2)
plt.plot(y,x,"b")

# %% [markdown]
# ### Object Oriented Method

# %%
fig = plt.figure() 

axes = fig.add_axes([0.1,0.1,0.8,0.8]) # [left, bottom, width, height] 
axes.plot(x,y)
axes.set_xlabel("X Label")
axes.set_ylabel("Y Label")
axes.set_title("Set Title")
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
# https://www.geeksforgeeks.org/how-to-add-axes-to-a-figure-in-matplotlib-with-python/

# %%
# [left, bottom, width, height] 
# all value between 0-1

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.8,0.4,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.7,0.8,0.4,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.7,0.8,0.9,0.5])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.7,0.8,0.9,0.5])
axes1.plot(x,y)
axes2.plot(y,x)

# %%
#Part 2

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)
for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 1, ncols = 2)
axes[0].plot(x,y)
axes[1].plot(y,x)
axes[0].set_title("First")
axes[1].set_title("Second")

plt.tight_layout() #For overlapping

# %% [markdown]
# ## Figure Size and DPI

# %%
fig = plt.figure(figsize = (3,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure(figsize = (6,5))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure(figsize = (8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig

# %%
fig.savefig("my_picture.jpg")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,label = "x**2")

# ax.set_title("Title")
# ax.set_ylabel("Y")
# ax.set_xlabel("X")

ax.plot(x,x**3,label = "x**3")

ax.legend()

# %%
# Look at matplotlib website

# %%
## Part3

# %% [markdown]
# # plot appearance

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple") # #RGB hex code

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",linewidth = 10)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",linewidth = 3,alpha = 0.2)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",linewidth = 2,linestyle = "--")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",lw = 2,ls = "--")

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",linewidth = 2,linestyle = "--",marker = "o")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple",linewidth = 2,
        linestyle = "--",
        marker = "o",
        markersize = 15,
       markerfacecolor = "red",
       markeredgewidth = 5)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = "purple", lw = 2, ls="--")

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)
